# %% [markdown]
# <a href="https://colab.research.google.com/github/akash-dev11/AIML/blob/main/Python/Basic/Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #COMMENTS

# %%
# This is the second day of learning python

# %% [markdown]
# #Variables

# %%
name = "Akash"
age = 21
print(name)
print(age)
# Out:
# Akash
# 21

# %% [markdown]
# # Variable Naming rules
# 1. Start :Alphabet, _
# 2. Middle or End : Alphabet , _ , Number

# %%
first_name = "Akash"
last_name = "Kumar"
print(first_name,last_name)
# Out:
# Akash Kumar

# %%
college = "Shiva inter"
college = "AITD"
print(college)
# Out:
# AITD

# %% [markdown]
# #Data Types
# 1. Integer -> int (50,0,-12,)
# 2. Float -> decimal (4.5,0.45,-45.3)
# 3. String -> str ("akash","age")
# 4. Boolean -> bool (True/False)

# %%
name = "akash"
age = 34
print(type(name))
print(type(age))
print(type(True))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'bool'>

# %% [markdown]
# # Taking input from the user

# %%
name = input("Enter the name:")
print(name)
# Out:
# Enter the name:Akash
# Akash

# %% [markdown]
# #Type Casting

# %%
a = int(input("Enter number first:"))
b = int(input("Enter number second"))
print(a+b)
# Out:
# Enter number first:23
# Enter number second54
# 77

# %%
Birth_year = int(input("Enter the birth year:"))
age = 2026-Birth_year
print(age)
# Out:
# Enter the birth year:2005
# 21
