# %% [markdown]
# <a href="https://colab.research.google.com/github/akash-dev11/AIML/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Essentials

# %%
print("hello world")
# Out:
# hello world

# %%
print("a")
print("b")
print("c")
# Out:
# a
# b
# c

# %%
print("a","b","c")
# Out:
# a b c
